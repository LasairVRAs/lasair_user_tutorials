# %% [markdown]
# UnderConstruction - I have not used the BBB features myself yet so I will dive into the notebooks later.
#
# see the [original tutorials](https://github.com/lsst-uk/lasair-examples/tree/main/features/bazinBlackBody)
